# %%
import qiskit

# %%
import numpy as np

# %%
# definindo um numero complexo
z = 2 + 3j

# %%
print(z)
# Out:
# (2+3j)

# %%
# módulo de a
abs(z)
# Out:
# 3.605551275463989

# %%
w = 5 - 2j

# %%
print(w)
# Out:
# (5-2j)

# %%
abs(w)
# Out:
# 5.385164807134504

# %%
#w/z
(5-2j)/(2+3j)
# Out:
# (0.30769230769230765-1.4615384615384617j)

# %%
#conjugado do z
np.conjugate(z)
# Out:
# (2-3j)

# %%
#conjugado do w
np.conjugate(w)
# Out:
# (5+2j)
